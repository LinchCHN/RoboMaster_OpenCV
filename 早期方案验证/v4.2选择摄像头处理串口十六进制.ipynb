# %%
import cv2
import numpy as np

# 获取所有可用摄像头
num_cameras = 10  # 假设最多有10个摄像头
available_cameras = []
for i in range(num_cameras):
    cap = cv2.VideoCapture(i)
    if cap.isOpened():
        available_cameras.append(i)
        cap.release()

# 可用摄像头列表
print("可用摄像头:")
for idx in available_cameras:
    print(f"摄像头 {idx}")
# 选择
selected_camera = int(input("请输入要使用的摄像头编号: "))
# 打开
video = cv2.VideoCapture(selected_camera)
# 检查
if video.isOpened():
    print(f"摄像头 {selected_camera} 已成功打开。")
else:
    print(f"无法打开选择的摄像头（摄像头 {selected_camera}）。请检查摄像头是否连接正常。")
    exit()
# Out:
# 可用摄像头:
# 摄像头 0
# 摄像头 1
# 摄像头 2
# 摄像头 3
# 摄像头 4
# 摄像头 5
# 请输入要使用的摄像头编号: 5
# 摄像头 5 已成功打开。

# %%
import serial.tools.list_ports 
import struct 
import re  # 导入正则表达式模块

while True:

    # 从摄像头读取一帧
    ret, img = video.read()

    # 如果读取失败，退出循环
    if not ret:
        break

    # 将图像从BGR转换为HSV颜色空间
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

    # 定义蓝色的HSV范围
    lower_blue = np.array([100, 50, 50])
    upper_blue = np.array([130, 255, 255])

    # 创建蓝色的掩码
    blue_mask = cv2.inRange(hsv, lower_blue, upper_blue)

    # 对掩码应用高斯模糊
    blue_mask = cv2.GaussianBlur(blue_mask, (5, 5), 0)

    # 获取二值图像的尺寸
    whole_h, _ = blue_mask.shape[:2]

    # 在蓝色掩码中查找轮廓
    _,contours, _ = cv2.findContours(image=blue_mask, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)

    # 将轮廓转换为列表并按面积降序排列
    contours = sorted(contours, key=lambda c: cv2.contourArea(c), reverse=True)[:5]

    # 存储矩形宽度、高度和点的数组
    rects = []

    # 遍历前5个轮廓
    for cont in contours:
        # 获取边界矩形的坐标和尺寸
        x, y, w, h = cv2.boundingRect(cont)

        # 检查有效矩形的条件
        if h / w >= 2 and h / whole_h > 0.1 and h > w:
            rects.append([x, y, w, h])

    # 找到面积最接近的两个矩形
    min_value = float('inf')
    best_rects = []

    for i in range(len(rects) - 1):
        for j in range(i + 1, len(rects)):
            value = abs(rects[i][2] * rects[i][3] - rects[j][2] * rects[j][3])
            if value < min_value:
                min_value = value
                best_rects = [rects[i], rects[j]]

    # 如果找到了两个最近矩形
    if best_rects:
        # 计算并打印矩形的四个角点
        rectangle1, rectangle2 = best_rects
        point1 = [rectangle1[0] + rectangle1[2] / 2, rectangle1[1]]
        point2 = [rectangle1[0] + rectangle1[2] / 2, rectangle1[1] + rectangle1[3]]
        point3 = [rectangle2[0] + rectangle2[2] / 2, rectangle2[1]]
        point4 = [rectangle2[0] + rectangle2[2] / 2, rectangle2[1] + rectangle2[3]]

         # 两边两个点的中间坐标
        center_point1 = [(point1[0] + point2[0]) / 2, (point1[1] + point2[1]) / 2]
        center_point2 = [(point3[0] + point4[0]) / 2, (point3[1] + point4[1]) / 2]
        #中心坐标
        middle_point = [(center_point1[0] + center_point2[0]) / 2, (center_point1[1] + center_point2[1]) / 2]

        #print(point1, point2, point3, point4)
        #print("Center Points:", center_point1, center_point2)
        print("Middle Point:", middle_point)

        # 定义矩形为多边形并在原始图像上绘制它
        pts = np.array([point1, point2, point4, point3], np.int32).reshape((-1, 1, 2))
        cv2.polylines(img, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

        #cv2.circle(img, (int(center_point1[0]), int(center_point1[1])), radius=5, color=(255, 0, 0), thickness=-1)
        #cv2.circle(img, (int(center_point2[0]), int(center_point2[1])), radius=5, color=(0, 0, 255), thickness=-1)
        cv2.circle(img, (int(middle_point[0]), int(middle_point[1])), radius=5, color=(0, 255, 255), thickness=-1)

        # 获取可用的串口列表
        available_ports = list(serial.tools.list_ports.comports())
        # 打开串口
        # 如果有可用的串口，则打开第一个串口
        if available_ports:
            port = available_ports[0][0]
            ser = serial.Serial(port, 9600)
        
        # 提取百位
            hex_middle_point_0 = int(middle_point[0] // 100)
            if hex_middle_point_0 < 10:
                hex_middle_point_0 = f'0{hex_middle_point_0}'
            else:
                hex_middle_point_0 = str(hex_middle_point_0)
        # 提取十位和个位
            hex_middle_point_1 = int(middle_point[0] % 100)
            if hex_middle_point_1 < 10:
                hex_middle_point_1 = f'0{hex_middle_point_1}'
            else:
                hex_middle_point_1 = str(hex_middle_point_1)
        # 提取小数点后两位
            hex_middle_point_2 = int((middle_point[0] % 1) * 100)
        # 提取百位以上2
            hex_middle_point_3 = int(middle_point[1] // 100)
            if hex_middle_point_3 < 10:
                hex_middle_point_3 = f'0{hex_middle_point_3}'
            else:
                hex_middle_point_3 = str(hex_middle_point_3)
        # 提取十位和个位2
            hex_middle_point_4 = int(middle_point[1] % 100)
            if hex_middle_point_4 < 10:
                hex_middle_point_4 = f'0{hex_middle_point_4}'
            else:
                hex_middle_point_4 = str(hex_middle_point_4)
        # 提取小数点后两位2
            hex_middle_point_5 = int((middle_point[1] % 1) * 100)
            
            hex_string = f'0x0A 0x0B 0x{hex_middle_point_0} 0x{hex_middle_point_1} 0x{hex_middle_point_2} 0x{hex_middle_point_3} 0x{hex_middle_point_4} 0x{hex_middle_point_5} 0x0C 0x0D'
        
            print("Hex String:", hex_string)
        # 发送数据到串口
            try:
                # 将字符串写入串口
                ser.write(bytes.fromhex(hex_string))
                print("成功发送十六进制字符串到USB.")
            except Exception as e:
                print(f"发生错误：{e}")
            finally: 
            # 发送换行符
                ser.write(b'\n')
            # 关闭串口
                ser.close()
        else:
            print("未找到可用的 COM 端口。")

    # 显示摄像头画面
    cv2.imshow('Camera Feed', img)

    # 检查是否按下 'q' 键以退出循环
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
#释放摄像头资源和关闭窗口
video.release() 
cv2.destroyAllWindows()
# Out:
# Middle Point: [174.75, 354.75]
# Hex String: 0x0A 0x0B 0x01 0x74 0x75 0x03 0x54 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [175.0, 354.75]
# Hex String: 0x0A 0x0B 0x01 0x75 0x0 0x03 0x54 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [170.75, 354.5]
# Hex String: 0x0A 0x0B 0x01 0x70 0x75 0x03 0x54 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [170.25, 354.0]
# Hex String: 0x0A 0x0B 0x01 0x70 0x25 0x03 0x54 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [172.25, 354.25]
# Hex String: 0x0A 0x0B 0x01 0x72 0x25 0x03 0x54 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 223.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x23 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 230.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x30 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 217.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x17 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 226.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x26 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 219.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x19 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 228.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 218.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x18 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 224.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x24 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 226.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 220.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 219.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x19 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 220.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 228.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x28 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [224.75, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x24 0x75 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 225.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x25 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 224.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x24 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 226.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 217.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x17 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 217.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x17 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 223.25]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 226.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 223.25]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 227.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x27 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 224.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x24 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [210.0, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x10 0x0 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 218.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 219.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x19 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 223.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x23 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.5, 219.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x50 0x02 0x19 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.25, 231.25]
# Hex String: 0x0A 0x0B 0x02 0x31 0x25 0x02 0x31 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 218.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 232.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x32 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 224.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 223.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 224.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x24 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 219.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x19 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 228.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [257.0, 100.25]
# Hex String: 0x0A 0x0B 0x02 0x57 0x0 0x01 0x00 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 215.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x15 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 226.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 219.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x19 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 217.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x17 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 227.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x27 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 233.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x33 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.25, 228.5]
# Hex String: 0x0A 0x0B 0x02 0x30 0x25 0x02 0x28 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 210.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x10 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 226.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.0, 223.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x0 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 223.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x23 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 231.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x31 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 228.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 228.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x28 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [224.75, 225.25]
# Hex String: 0x0A 0x0B 0x02 0x24 0x75 0x02 0x25 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 223.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x23 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 218.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 218.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.0, 230.75]
# Hex String: 0x0A 0x0B 0x02 0x30 0x0 0x02 0x30 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 224.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x24 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 224.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 219.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x19 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 224.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x24 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 224.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x24 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 231.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x31 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 231.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x31 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 225.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x25 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 220.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 229.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x29 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 227.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x27 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 229.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x29 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 223.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x23 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [145.0, 337.0]
# Hex String: 0x0A 0x0B 0x01 0x45 0x0 0x03 0x37 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [224.5, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x24 0x50 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 220.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 227.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x27 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 227.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x27 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 226.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 225.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 223.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 226.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x26 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.75, 219.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x75 0x02 0x19 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 228.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x28 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 222.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x22 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.0, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x0 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 228.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x28 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.0, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x0 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 226.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.0, 220.75]
# Hex String: 0x0A 0x0B 0x02 0x30 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 214.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x14 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 225.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x25 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 238.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x38 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 224.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 221.75]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 229.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x29 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 229.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x29 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 228.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 217.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x17 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 228.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x28 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 217.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x17 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 222.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 223.25]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 226.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 226.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x26 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.75, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x75 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 226.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 229.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x29 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 219.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x19 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 220.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.25, 224.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x25 0x02 0x24 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 226.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.0, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x0 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 219.5]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x19 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.0, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x30 0x0 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.5, 225.5]
# Hex String: 0x0A 0x0B 0x02 0x30 0x50 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 222.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x22 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.5, 221.5]
# Hex String: 0x0A 0x0B 0x02 0x30 0x50 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 215.25]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x15 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.0, 219.0]
# Hex String: 0x0A 0x0B 0x02 0x31 0x0 0x02 0x19 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.0, 218.0]
# Hex String: 0x0A 0x0B 0x02 0x32 0x0 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 217.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x17 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 216.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x16 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.5, 227.75]
# Hex String: 0x0A 0x0B 0x02 0x30 0x50 0x02 0x27 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 216.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x16 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.25, 216.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x25 0x02 0x16 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.5, 219.5]
# Hex String: 0x0A 0x0B 0x02 0x30 0x50 0x02 0x19 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 224.0]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x24 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 215.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x15 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.75, 215.75]
# Hex String: 0x0A 0x0B 0x02 0x32 0x75 0x02 0x15 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.75, 224.5]
# Hex String: 0x0A 0x0B 0x02 0x32 0x75 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.0, 213.0]
# Hex String: 0x0A 0x0B 0x02 0x32 0x0 0x02 0x13 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 219.75]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x19 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 213.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x13 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.25, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x32 0x25 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.75, 213.75]
# Hex String: 0x0A 0x0B 0x02 0x32 0x75 0x02 0x13 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.25, 215.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x25 0x02 0x15 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.75, 218.0]
# Hex String: 0x0A 0x0B 0x02 0x31 0x75 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.25, 216.75]
# Hex String: 0x0A 0x0B 0x02 0x32 0x25 0x02 0x16 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.5, 215.75]
# Hex String: 0x0A 0x0B 0x02 0x31 0x50 0x02 0x15 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.5, 214.75]
# Hex String: 0x0A 0x0B 0x02 0x32 0x50 0x02 0x14 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.5, 213.5]
# Hex String: 0x0A 0x0B 0x02 0x30 0x50 0x02 0x13 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 213.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x13 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.75, 213.25]
# Hex String: 0x0A 0x0B 0x02 0x31 0x75 0x02 0x13 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [146.25, 329.0]
# Hex String: 0x0A 0x0B 0x01 0x46 0x25 0x03 0x29 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.75, 221.25]
# Hex String: 0x0A 0x0B 0x02 0x31 0x75 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.25, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x31 0x25 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 213.0]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x13 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.0, 215.75]
# Hex String: 0x0A 0x0B 0x02 0x32 0x0 0x02 0x15 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.25, 216.75]
# Hex String: 0x0A 0x0B 0x02 0x32 0x25 0x02 0x16 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 213.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x13 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.25, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x32 0x25 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 215.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x15 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.25, 215.5]
# Hex String: 0x0A 0x0B 0x02 0x32 0x25 0x02 0x15 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 218.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x18 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.75, 210.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x75 0x02 0x10 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 217.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x17 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 217.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x17 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.0, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x32 0x0 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.0, 214.75]
# Hex String: 0x0A 0x0B 0x02 0x29 0x0 0x02 0x14 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.75, 218.5]
# Hex String: 0x0A 0x0B 0x02 0x31 0x75 0x02 0x18 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.0, 213.5]
# Hex String: 0x0A 0x0B 0x02 0x31 0x0 0x02 0x13 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.5, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x31 0x50 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [232.25, 216.5]
# Hex String: 0x0A 0x0B 0x02 0x32 0x25 0x02 0x16 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 213.5]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x13 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 213.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x13 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.25, 219.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x25 0x02 0x19 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [231.75, 215.0]
# Hex String: 0x0A 0x0B 0x02 0x31 0x75 0x02 0x15 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.0, 220.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x0 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [230.5, 218.25]
# Hex String: 0x0A 0x0B 0x02 0x30 0x50 0x02 0x18 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.25, 215.5]
# Hex String: 0x0A 0x0B 0x02 0x27 0x25 0x02 0x15 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 215.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x15 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 215.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x15 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 215.25]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x15 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 214.25]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x14 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.25, 215.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x25 0x02 0x15 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.5, 221.0]
# Hex String: 0x0A 0x0B 0x02 0x29 0x50 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.75, 213.0]
# Hex String: 0x0A 0x0B 0x02 0x28 0x75 0x02 0x13 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 220.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.5, 219.5]
# Hex String: 0x0A 0x0B 0x02 0x28 0x50 0x02 0x19 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 216.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x16 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [229.25, 222.25]
# Hex String: 0x0A 0x0B 0x02 0x29 0x25 0x02 0x22 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.5, 212.5]
# Hex String: 0x0A 0x0B 0x02 0x26 0x50 0x02 0x12 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [228.0, 216.25]
# Hex String: 0x0A 0x0B 0x02 0x28 0x0 0x02 0x16 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.0, 214.75]
# Hex String: 0x0A 0x0B 0x02 0x26 0x0 0x02 0x14 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [225.25, 213.5]
# Hex String: 0x0A 0x0B 0x02 0x25 0x25 0x02 0x13 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [226.75, 210.0]
# Hex String: 0x0A 0x0B 0x02 0x26 0x75 0x02 0x10 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.75, 216.0]
# Hex String: 0x0A 0x0B 0x02 0x27 0x75 0x02 0x16 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [227.5, 214.75]
# Hex String: 0x0A 0x0B 0x02 0x27 0x50 0x02 0x14 0x75 0x0C 0x0D
# ...
# Middle Point: [186.75, 220.5]
# Hex String: 0x0A 0x0B 0x01 0x86 0x75 0x02 0x20 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 218.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x18 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [187.75, 227.75]
# Hex String: 0x0A 0x0B 0x01 0x87 0x75 0x02 0x27 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 226.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 226.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.5, 230.75]
# Hex String: 0x0A 0x0B 0x01 0x86 0x50 0x02 0x30 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [185.0, 220.0]
# Hex String: 0x0A 0x0B 0x01 0x85 0x0 0x02 0x20 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 219.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x19 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 223.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 223.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.5, 220.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x50 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.5, 223.25]
# Hex String: 0x0A 0x0B 0x01 0x83 0x50 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [92.5, 352.75]
# Hex String: 0x0A 0x0B 0x00 0x92 0x50 0x03 0x52 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.0, 224.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x0 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.0, 224.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x0 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 220.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.75, 221.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x75 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 230.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x30 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 225.5]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.25, 225.5]
# Hex String: 0x0A 0x0B 0x01 0x86 0x25 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.25, 225.5]
# Hex String: 0x0A 0x0B 0x01 0x86 0x25 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.75, 226.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x75 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.25, 233.75]
# Hex String: 0x0A 0x0B 0x01 0x86 0x25 0x02 0x33 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 225.5]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.0, 220.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x0 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.0, 223.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x0 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [187.25, 225.75]
# Hex String: 0x0A 0x0B 0x01 0x87 0x25 0x02 0x25 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.75, 223.5]
# Hex String: 0x0A 0x0B 0x01 0x82 0x75 0x02 0x23 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 230.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x30 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.5, 224.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x50 0x02 0x24 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.0, 223.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x0 0x02 0x23 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 225.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x25 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.25, 222.0]
# Hex String: 0x0A 0x0B 0x01 0x82 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [185.0, 227.25]
# Hex String: 0x0A 0x0B 0x01 0x85 0x0 0x02 0x27 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 225.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x25 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 226.25]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [185.75, 235.5]
# Hex String: 0x0A 0x0B 0x01 0x85 0x75 0x02 0x35 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [185.0, 220.25]
# Hex String: 0x0A 0x0B 0x01 0x85 0x0 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.0, 225.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x0 0x02 0x25 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.0, 226.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x0 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 225.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x25 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.5, 225.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x50 0x02 0x25 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [185.5, 224.5]
# Hex String: 0x0A 0x0B 0x01 0x85 0x50 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [185.0, 222.0]
# Hex String: 0x0A 0x0B 0x01 0x85 0x0 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.5, 228.25]
# Hex String: 0x0A 0x0B 0x01 0x83 0x50 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 226.0]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x26 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 225.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x25 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.5, 227.0]
# Hex String: 0x0A 0x0B 0x01 0x86 0x50 0x02 0x27 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 218.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x18 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 220.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x20 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 219.5]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x19 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.0, 221.25]
# Hex String: 0x0A 0x0B 0x01 0x86 0x0 0x02 0x21 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 227.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x27 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [187.0, 230.5]
# Hex String: 0x0A 0x0B 0x01 0x87 0x0 0x02 0x30 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.75, 228.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x75 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 221.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [188.0, 229.0]
# Hex String: 0x0A 0x0B 0x01 0x88 0x0 0x02 0x29 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 224.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 227.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x27 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.25, 227.0]
# Hex String: 0x0A 0x0B 0x01 0x86 0x25 0x02 0x27 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 221.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x21 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 228.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x28 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 223.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.25, 220.25]
# Hex String: 0x0A 0x0B 0x01 0x83 0x25 0x02 0x20 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.0, 223.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x0 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.5, 226.25]
# Hex String: 0x0A 0x0B 0x01 0x86 0x50 0x02 0x26 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 225.25]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x25 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [187.25, 228.25]
# Hex String: 0x0A 0x0B 0x01 0x87 0x25 0x02 0x28 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.75, 221.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x75 0x02 0x21 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 221.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x21 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 224.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 225.75]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x25 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.25, 222.0]
# Hex String: 0x0A 0x0B 0x01 0x84 0x25 0x02 0x22 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.75, 229.0]
# Hex String: 0x0A 0x0B 0x01 0x83 0x75 0x02 0x29 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [186.25, 223.75]
# Hex String: 0x0A 0x0B 0x01 0x86 0x25 0x02 0x23 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [188.5, 229.25]
# Hex String: 0x0A 0x0B 0x01 0x88 0x50 0x02 0x29 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [187.0, 223.25]
# Hex String: 0x0A 0x0B 0x01 0x87 0x0 0x02 0x23 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [184.5, 224.5]
# Hex String: 0x0A 0x0B 0x01 0x84 0x50 0x02 0x24 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 200.75]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x02 0x00 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 198.75]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x01 0x98 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 198.75]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x01 0x98 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 198.75]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x01 0x98 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [180.5, 199.75]
# Hex String: 0x0A 0x0B 0x01 0x80 0x50 0x01 0x99 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [180.75, 198.25]
# Hex String: 0x0A 0x0B 0x01 0x80 0x75 0x01 0x98 0x25 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.25, 202.5]
# Hex String: 0x0A 0x0B 0x01 0x82 0x25 0x02 0x02 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [180.5, 201.5]
# Hex String: 0x0A 0x0B 0x01 0x80 0x50 0x02 0x01 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 201.75]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x02 0x01 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.0, 200.0]
# Hex String: 0x0A 0x0B 0x01 0x82 0x0 0x02 0x00 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.0, 201.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x0 0x02 0x01 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.0, 201.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x0 0x02 0x01 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.25, 199.5]
# Hex String: 0x0A 0x0B 0x01 0x81 0x25 0x01 0x99 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [183.0, 214.75]
# Hex String: 0x0A 0x0B 0x01 0x83 0x0 0x02 0x14 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.5, 205.0]
# Hex String: 0x0A 0x0B 0x01 0x81 0x50 0x02 0x05 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.75, 199.75]
# Hex String: 0x0A 0x0B 0x01 0x82 0x75 0x01 0x99 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.75, 199.75]
# Hex String: 0x0A 0x0B 0x01 0x82 0x75 0x01 0x99 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 203.75]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x02 0x03 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 200.5]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x02 0x00 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.75, 203.5]
# Hex String: 0x0A 0x0B 0x01 0x82 0x75 0x02 0x03 0x50 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [181.75, 202.0]
# Hex String: 0x0A 0x0B 0x01 0x81 0x75 0x02 0x02 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.0, 201.75]
# Hex String: 0x0A 0x0B 0x01 0x82 0x0 0x02 0x01 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.25, 198.75]
# Hex String: 0x0A 0x0B 0x01 0x82 0x25 0x01 0x98 0x75 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
# Middle Point: [182.0, 203.0]
# Hex String: 0x0A 0x0B 0x01 0x82 0x0 0x02 0x03 0x0 0x0C 0x0D
# 发生错误：non-hexadecimal number found in fromhex() arg at position 1
